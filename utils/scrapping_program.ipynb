# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import date
import locale

# %%
page = requests.get("https://www.ifrap.org/comparateurs/presidentielle-2022")

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
columns = ['Theme', 'Sub-theme', 'Candidate', 'Proposition', 'Priority', 'Keywords', 'Data_origin', 'Data_source', 'Created_at', 'Updated_at']

# %%
# propositions_list = []

# soup = BeautifulSoup(page.content, 'html.parser')
# sections = soup.find_all('div', {'class' : 'mx-auto p-4 max-w-screen-lg lg:px-6'})[0]
# for section in sections:
#     theme = section.find('h2').get_text()
#     details = section.find_all('details', {'class' : 'border-t border-gray-100 last-of-type:rounded-b pe'})
#     for detail in details:
#         sub_theme = detail.select('summary')[0].get_text().replace('\n','')
#         ul = detail.find_all('ul', {'class' : 'divide-y'})[0]
#         for li in ul:
#             # print(li.prettify())
#             candidate_name = li.select('figure')[0].get_text()
#             # propositions = li.select('div')[0].find_all('p')
#             test_propositions = li.select('div')[0].find_all('ol')
#             test_key_figures = li.select('div')[0].find_all('div', {'class' : 'mt-4 p-4 rounded-lg border shadow text-sm'})
#             test_no_propositions = li.select('div')[0].find_all('p', {'class' : 'text-gray-400'})

#             if test_key_figures:
#                 key_figure = test_key_figures[0].get_text()
#                 key_figures_detail = [theme, sub_theme, candidate_name, key_figure, 1, "", "Programme", "IFRAP", date.today(), date.today()] # Attention des fois l'origine des données ne provient pas des candidats mais de l'IFRAP, rajouter une fonction pour éviter ce phénomène 
#                 propositions_list.append(key_figures_detail)

#             if test_propositions:
#                 # print(test_propositions[0].find_all('p'))
#                 for proposition in test_propositions[0].find_all('p'):
#                     proposition_name = proposition.get_text()
#                     # if not "Chiffre clé" in proposition_name:
#                     proposition_detail = [theme, sub_theme, candidate_name, proposition_name, 0, "", "Programme", "IFRAP", date.today(), date.today()]
#                     propositions_list.append(proposition_detail)

#             if test_no_propositions:
#                 candidate_detail = [theme, sub_theme, candidate_name, "Proposition non encore connue", -1, "", "Programme", "IFRAP", date.today(), date.today()]
#                 propositions_list.append(candidate_detail)

# %%
# propositions_df = pd.DataFrame(propositions_list, columns = columns)
# propositions_df

# %%
propositions_list = []

soup = BeautifulSoup(page.content, 'html.parser')
sections = soup.find_all('div', {'class' : 'mx-auto p-4 max-w-screen-lg lg:px-6'})[0]
for section in sections:
    theme = section.find('h2').get_text()
    details = section.find_all('details', {'class' : 'border-t border-gray-100 last-of-type:rounded-b pe'})
    for detail in details:
        sub_theme = detail.select('summary')[0].get_text().replace('\n','')
        ul = detail.find_all('ul', {'class' : 'divide-y'})[0]
        for li in ul:
            candidate_name = li.select('figure')[0].get_text()
            test_propositions = li.select('div')[0].find_all('ol')
            test_key_figures = li.select('div')[0].find_all('div', {'class' : 'mt-4 p-4 rounded-lg border shadow text-sm'})
            test_no_propositions = li.select('div')[0].find_all('p', {'class' : 'text-gray-400'})

            if test_key_figures: # A Reformater 
                key_figure = test_key_figures[0].get_text()
                key_figures_detail = [theme, sub_theme, candidate_name, key_figure, 1, "", "Programme", "IFRAP", date.today(), date.today()] # Attention des fois l'origine des données ne provient pas des candidats mais de l'IFRAP, rajouter une fonction pour éviter ce phénomène 
                propositions_list.append(key_figures_detail)

            if test_propositions:

                test_details = test_propositions[0].find_all('details')
                if test_details:
                    for past_proposition in test_details[0].find_all('p'):
                        past_proposition_name = past_proposition.get_text()
                        past_proposition_detail = [theme, sub_theme, candidate_name, past_proposition_name, -2, "", "Programme", "IFRAP", date.today(), date.today()]
                        propositions_list.append(past_proposition_detail)

                # print(test_propositions[0].find_all('p'))
                for proposition in test_propositions[0].find_all('p'):
                    proposition_name = proposition.get_text()
                    proposition_detail = [theme, sub_theme, candidate_name, proposition_name, 0, "", "Programme", "IFRAP", date.today(), date.today()]
                    propositions_list.append(proposition_detail)

            if test_no_propositions:
                candidate_detail = [theme, sub_theme, candidate_name, "Proposition non encore connue", -1, "", "Programme", "IFRAP", date.today(), date.today()]
                propositions_list.append(candidate_detail)

# %%
propositions_df = pd.DataFrame(propositions_list, columns = columns)
propositions_df
# Out:
#                     Theme                                   Sub-theme  \
# 0     Social & Solidarité      Allocations & prestations sociales
# 1     Social & Solidarité      Allocations & prestations sociales
# 2     Social & Solidarité      Allocations & prestations sociales
# 3     Social & Solidarité      Allocations & prestations sociales
# 4     Social & Solidarité      Allocations & prestations sociales
# ..                    ...                                         ...
# 959             Fiscalité          IS & fiscalité des entreprises
# 960             Fiscalité          IS & fiscalité des entreprises
# 961             Fiscalité          IS & fiscalité des entreprises
# 962             Fiscalité          IS & fiscalité des entreprises
# 963             Fiscalité          IS & fiscalité des entreprises
#
#                    Candidate  \
# 0     Nicolas  Dupont-Aignan
# 1     Nicolas  Dupont-Aignan
# 2     Nicolas  Dupont-Aignan
# 3     Nicolas  Dupont-Aignan
# 4     Nicolas  Dupont-Aignan
# ..                       ...
# 959            Eric Zemmour
# 960            Eric Zemmour
# 961            Eric Zemmour
# 962            Eric Zemmour
# 963            Eric Zemmour
#
#                                            Proposition  Priority Keywords  \
# 0    Une journée par semaine de service pour la col...         0
# 1        Revalorisation et déconjugalisation de l’AAH.         0
# 2    Majoration des allocations familiales pour les...         0
# 3    Allocations et quotients familiaux, prestation...         0
# 4    Création d’un congé parental rémunéré à 75% du...         0
# ..                                                 ...       ...      ...
# 959  Baisse de l'IS et réduction des charges sociales.         0
# 960  Réduction de l'impôt sur les sociétés à 15 % p...         0
# 961  Suppression des droits de transmission des ent...         0
# 962  Défiscaliser la prime de participation pour le...         0
# 963  Exonérer totalement d'impôts et de charges soc...         0
#
#     Data_origin Data_source  Created_at  Updated_at
# 0     Programme       IFRAP  2022-01-17  2022-01-17
# 1     Programme       IFRAP  2022-01-17  2022-01-17
# 2     Programme       IFRAP  2022-01-17  2022-01-17
# 3     Programme       IFRAP  2022-01-17  2022-01-17
# 4     Programme       IFRAP  2022-01-17  2022-01-17
# ..          ...         ...         ...         ...
# 959   Programme       IFRAP  2022-01-17  2022-01-17
# 960   Programme       IFRAP  2022-01-17  2022-01-17
# 961   Programme       IFRAP  2022-01-17  2022-01-17
# 962   Programme       IFRAP  2022-01-17  2022-01-17
# 963   Programme       IFRAP  2022-01-17  2022-01-17
#
# [964 rows x 10 columns]

# %%
# def scrape_programs(url):
#     """
#     Get every propositions 
#     """
#     # get the response in the form of html
#     table_class="wikitable sortable jquery-tablesorter"
#     response=requests.get(wikiurl)
#     # parse data from the html into a beautifulsoup object
#     soup = BeautifulSoup(response.text, 'html.parser')
#     table=soup.find('table',{'class':"wikitable"})
#     df=pd.read_html(str(table))
#     return df
